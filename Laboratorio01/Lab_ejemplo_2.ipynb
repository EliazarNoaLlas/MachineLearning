# %% [markdown]
# # **Parte 1**
# Importamos y mostramos los datos del curso de Compiladores (laboratorio)en formato xlsx (excel).
#
# En la parte izquierda se debe subir el archivo correspondiente

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('Compi_Lab_A.xlsx')

# %%
df            #imprime todo el conjunto de datos
# Out:
#     Codigo               Apellidos y nombres  N1  N2  N3
# 0   113561        MAXDEO-LAGOS-KEVIN ROUSBEL  15  19  13
# 1   182921   MOLLINEDO-PEÑA-ALVARO SEBASTIAN  16  17  14
# 2   182923      MORA-CCARHUARUPAY-LUZ LUCERO  15  19  13
# 3   161369          MUÑOZ-MUÑOZ-WILY RODRIGO  15  16  13
# 4   171565  MUÑOZ-PACHECO-CHRISTIAN FERNANDO  16  17  14
# 5   182928   PUMA-SOTOMAYOR-RICHARD MIHAYLOR  16  17  14
# 6   110603   PUMAYALLI-CUSICUNA-FRANK EDISON  15  19  13
# 7   174447   QUISPE-CHAMBILLA-CARLOS ENRIQUE  20  18  20
# 8   113567        QUISPE-HUARHUA-IVAN ARTHUR   0   0   0
# 9   160332       QUISPE-JIMENEZ-MIGUEL ANGEL  16  18  15
# 10  155179          QUISPE-LAROTA-YHON LENIN   0   0   0
# 11  174914      QUISPE-PALOMINO-LUIYI ANTONY  17  18  20
# 12  161135                QUISPE-TACURI-RUDI  16  18  15
# 13  171866            QUISPE-YAHUIRA-RONALDO  20  18  20
# 14  174452      SARCO-JACINTO-DANIEL EDUARDO  20  18  20
# ...

# %%
df.head(5)      #imprime las 5 primeros filas
# Out:
#    Codigo               Apellidos y nombres  N1  N2  N3
# 0  113561        MAXDEO-LAGOS-KEVIN ROUSBEL  15  19  13
# 1  182921   MOLLINEDO-PEÑA-ALVARO SEBASTIAN  16  17  14
# 2  182923      MORA-CCARHUARUPAY-LUZ LUCERO  15  19  13
# 3  161369          MUÑOZ-MUÑOZ-WILY RODRIGO  15  16  13
# 4  171565  MUÑOZ-PACHECO-CHRISTIAN FERNANDO  16  17  14

# %% [markdown]
# Extrae e imprime solo la columna con etiqueta N2

# %%
data = df['N2']

# %%
data
# Out:
# 0     19
# 1     17
# 2     19
# 3     16
# 4     17
# 5     17
# 6     19
# 7     18
# 8      0
# 9     18
# 10     0
# 11    18
# 12    18
# 13    18
# 14    18
# 15    18
# 16    20
# 17    18
# 18    20
# 19    20
# 20    18
# Name: N2, dtype: int64

# %%
# muestra el histograma con los datos de la columna N2
plt.hist(data)
plt.show()

# %% [markdown]
# # **Parte 2**
# Importamos y mostramos los datos del curso de Compiladores (laboratorio) en formato csv
#
# En la parte izquierda se debe subir el archivo correspondiente
#
# ***Nota:*** Asegurese que los Datos en el archivo esten separados por '**,**'
#
# la codificación: **UTF-8**
#
# extensión: **csv** ó **txt**

# %%
df = pd.read_csv('Compi_Lab_A.csv')

# %%
df.head()
# Out:
#    Codigo               Apellidos y nombres  N1  N2  N3
# 0  113561        MAXDEO-LAGOS-KEVIN ROUSBEL  15  19  13
# 1  182921   MOLLINEDO-PEÑA-ALVARO SEBASTIAN  16  17  14
# 2  182923      MORA-CCARHUARUPAY-LUZ LUCERO  15  19  13
# 3  161369          MUÑOZ-MUÑOZ-WILY RODRIGO  15  16  13
# 4  171565  MUÑOZ-PACHECO-CHRISTIAN FERNANDO  16  17  14

# %%
#obtener el promedio de N3 entre todos los alumnos
promedio = df['N3'].mean()
promedio
# Out:
# 15.047619047619047

# %%
# mostramos las notas minima y maxima de la primera parcial

print('primera nota minima = ',df['N1'].min())
print('primera nota maxima = ',df['N1'].max())
# Out:
# primera nota minima =  0
# primera nota maxima =  20

# %% [markdown]
# # **Parte 3**
#
# limpiamos el conjunto de datos en excel, quitandole las columnas y filas innecesarias y utilizamos solo columna N1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel('Compi_Lab_A.xlsx')

# %%
df.head()
# Out:
#    Codigo               Apellidos y nombres  N1  N2  N3
# 0  113561        MAXDEO-LAGOS-KEVIN ROUSBEL  15  19  13
# 1  182921   MOLLINEDO-PEÑA-ALVARO SEBASTIAN  16  17  14
# 2  182923      MORA-CCARHUARUPAY-LUZ LUCERO  15  19  13
# 3  161369          MUÑOZ-MUÑOZ-WILY RODRIGO  15  16  13
# 4  171565  MUÑOZ-PACHECO-CHRISTIAN FERNANDO  16  17  14

# %%
data = df['N1']

plt.hist(data, bins = 20)

plt.show()
