# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,5,11)
y = x**2

# %%
plt.plot(x,y,'rx')
plt.show()

# %%
plt.plot(x,y,'s-')
plt.show()

# %%
plt.plot(x,y,'d:')
plt.show()
